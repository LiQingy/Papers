# %%
# %pylab notebook
import numpy as np 
import h5py
import matplotlib.pyplot as plt
import random
import sys
sys.path.append('/home/qyli/oPDF2')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
fileCM = '../proxy/cluster/G3X-CM-masscomplete-ALL.txt'
filefit = '../proxy/cluster/GXsub_DM_fitmc_rcin200_100000_TMP.txt'
dataCM = np.loadtxt(fileCM)
datafit = np.loadtxt(filefit)
import oPDFplus as opd
mmtrue = datafit[:,0] / dataCM[:,2] * 1e15
cctrue = datafit[:,1] / dataCM[:,6]
loc = opd.sigma3sel(np.log10(mmtrue),np.log10(cctrue))
# Out:
# 318
# 312
# 311
# 310
# 310

# %%
maind = np.loadtxt('../proxy/GadgetX_DS_main')[loc,1:]

# %%
def calall_cov(nphy):
	phyall = [maind[:,25],maind[:,11],maind[:,24],maind[:,8],maind[:,2],maind[:,16],maind[:,1],maind[:,3],maind[:,5],maind[:,6],maind[:,0]]
	label = [r'$n_{e}$','$r2$','$T_{500}$','$M1$',r'$f_{\rm s}$',r'$\sigma_{\rm V}$',r'$\Delta_{\rm r}$',r'$\chi_{\rm DS}$',r'$\dot{M}_\mathrm{a}$',r'$f_{\rm ste}$',r'$\eta$']   
	
	covall = np.zeros(shape = (nphy,nphy))

	for i in range(nphy):
		for j in range(nphy-1-i):
			j = j+i+1
			pro1 = phyall[i]
			pro2 = phyall[j]
			# if label[i] == 'Ma' or label[j] == 'Ma':
			# 	pro1 = pro1[locMa0]
			# 	pro2 = pro2[locMa0]
			cov = np.cov(pro1,pro2)
			coveff = cov[0][1] / cov[0][0]**0.5 / cov[1][1]**0.5
			print('The correlation coefficient between %s and %s is %s' %(label[i],label[j],coveff))

			covall[i,j] = coveff
		covall[i,i] = 1
	covall = np.around(covall, 2)
	print(covall)
	return covall, label

def plot_d3(ax):
    nphy = 11
    covall,label = calall_cov(nphy)

    covmap = ax.imshow(np.abs(covall), cmap = 'Blues',vmin = 0, vmax = 1)
    plt.colorbar(covmap, shrink = 0.85)
#     cbar = ax.colorbar()
#     cbar.ax.set_ylabel(r'$|\gamma|$', fontsize = 12)

    ax.set_xticklabels(label,fontsize = 14)
    ax.set_yticklabels(label,fontsize = 14)
    ax.set_xticks(np.arange(len(label)))
    ax.set_yticks(np.arange(len(label)))

    for i in range(len(label)):
        for j in range(nphy-i):
            j = nphy - 1 - j 
            text = ax.text(j, i, '%.2f' %covall[i, j], fontsize = 8,
                            ha="center", va="center", color="k")				
    # plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #         rotation_mode="anchor")
    ax.invert_xaxis()
    ax.invert_yaxis()

    ax.tick_params( labelsize = 11, direction = 'out')
    bwith = 1.2 #边框宽度设置为2
    ax.spines['bottom'].set_linewidth(bwith)
    ax.spines['left'].set_linewidth(bwith)
    ax.spines['top'].set_linewidth(bwith)
    ax.spines['right'].set_linewidth(bwith)

# %%
## map all features
def calall_cov00(nphy):
	phyall = [maind[:,25],maind[:,11],maind[:,24],maind[:,8],maind[:,2],maind[:,16],maind[:,1],maind[:,3],maind[:,5],maind[:,6],maind[:,0]]
	label = [r'$n_{e}$','$r2$','$T_{500}$','$M1$',r'$f_{\rm s}$',r'$\sigma_{\rm V}$',r'$\Delta_{\rm r}$',r'$\chi_{\rm DS}$',r'$\dot{M}_\mathrm{a}$',r'$f_{\rm ste}$',r'$\eta$']   
	
	covall = np.zeros(shape = (nphy,nphy))

	for i in range(nphy):
		for j in range(nphy):
			pro1 = phyall[i]
			pro2 = phyall[j]
			# if label[i] == 'Ma' or label[j] == 'Ma':
			# 	pro1 = pro1[locMa0]
			# 	pro2 = pro2[locMa0]
			cov = np.cov(pro1,pro2)
			coveff = cov[0][1] / cov[0][0]**0.5 / cov[1][1]**0.5
			print('The correlation coefficient between %s and %s is %s' %(label[i],label[j],coveff))

			covall[i,j] = coveff
	covall = np.around(covall, 2)
	print(covall)
	return covall, label

def plot_d300(ax):
    nphy = 11
    covall,label = calall_cov00(nphy)

    covmap = ax.imshow(np.abs(covall), cmap = 'Blues',vmin = 0, vmax = 1)
    plt.colorbar(covmap, shrink = 0.85)
#     cbar = ax.colorbar()
#     cbar.ax.set_ylabel(r'$|\gamma|$', fontsize = 12)

    ax.set_xticklabels(label,fontsize = 14)
    ax.set_yticklabels(label,fontsize = 14)
    ax.set_xticks(np.arange(len(label)))
    ax.set_yticks(np.arange(len(label)))

    for i in range(len(label)):
        for j in range(nphy): 
            text = ax.text(j, i, '%.2f' %covall[i, j], fontsize = 8,
                            ha="center", va="center", color="k")				
    # plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
    #         rotation_mode="anchor")
    ax.invert_xaxis()
    ax.invert_yaxis()

    ax.tick_params( labelsize = 11, direction = 'out')
    bwith = 1.2 #边框宽度设置为2
    ax.spines['bottom'].set_linewidth(bwith)
    ax.spines['left'].set_linewidth(bwith)
    ax.spines['top'].set_linewidth(bwith)
    ax.spines['right'].set_linewidth(bwith)

# %% [markdown]
# ## plot observation indicators and D3 indicators

# %%
def calob_cov():
    dSZ = np.loadtxt('../proxy/GadgetX_DS_SZ')[loc,1:]
    dXray = np.loadtxt('../proxy/GadgetX_DS_Xray')[loc,1:]
    dOffset = np.loadtxt('../proxy/GadgetX_DS_Offset')[loc,1:]

    phyall = [dXray[:,2],dXray[:,-1],dSZ[:,-1],dOffset[:,1],dOffset[:,5],dOffset[:,2],dOffset[:,6]]
#     phyall = [dSZ[:,0],dSZ[:,1],dSZ[:,2],dSZ[:,3],dSZ[:,4],dSZ[:,5],dSZ[:,6]]
    d3fea = [maind[:,0], maind[:,5], maind[:,9], maind[:,-3]]
#     labelall = ['1','2','3','4','5','6','7']
    labelall = [r'$P_{\rm Xray}$', r'$M_{\rm Xray}$', r'$M_{\rm SZ}$', r'$R_{\rm SZ}$', r'$O_{\rm BCG-SZ}$', r'$R_{\rm X}$',r'$O_{\rm BCG-Py}$']
    labeld3 = [r'$\eta$',r'$\dot{M}_\mathrm{a}$','$M2$','$T_{500}$']
    covall = np.zeros(shape = (4,7))

    for i in range(4):
        for j in range(7):
            pro1 = d3fea[i]
            pro2 = phyall[j]
            cov = np.cov(pro1,pro2)
            coveff = cov[0][1] / cov[0][0]**0.5 / cov[1][1]**0.5
#             print('The correlation coefficient between %s and %s is %s' %(labeld3[i],labelall[j],coveff))

            covall[i,j] = coveff
    covall = np.around(covall, 2)
    print(covall)
    return covall, labelall, labeld3

# %% [markdown]
# ## plot a combination

# %%
fig, ax = plt.subplots(figsize = (5.5,5))

# plot_d3(ax) #map half grids
plot_d300(ax)

plt.tight_layout()
plt.show()
plt.savefig('./figs/cc1.pdf')
# Out:
# <img src="data:image/png;base64,..." width="550">
# The correlation coefficient between $n_{e}$ and $n_{e}$ is 0.9999999999999998
# The correlation coefficient between $n_{e}$ and $r2$ is 0.11490234459483518
# The correlation coefficient between $n_{e}$ and $T_{500}$ is 0.3449273547292609
# The correlation coefficient between $n_{e}$ and $M1$ is -0.04094715663522743
# The correlation coefficient between $n_{e}$ and $f_{\rm s}$ is -0.22143954017387651
# The correlation coefficient between $n_{e}$ and $\sigma_{\rm V}$ is 0.2975126827479209
# The correlation coefficient between $n_{e}$ and $\Delta_{\rm r}$ is -0.28016345540213367
# The correlation coefficient between $n_{e}$ and $\chi_{\rm DS}$ is 0.190507587124427
# The correlation coefficient between $n_{e}$ and $\dot{M}_\mathrm{a}$ is 0.02942700541036627
# The correlation coefficient between $n_{e}$ and $f_{\rm ste}$ is 0.19558344431651506
# The correlation coefficient between $n_{e}$ and $\eta$ is 0.015152284793599717
# The correlation coefficient between $r2$ and $n_{e}$ is 0.11490234459483518
# The correlation coefficient between $r2$ and $r2$ is 1.0000000000000002
# The correlation coefficient between $r2$ and $T_{500}$ is 0.0949155433992121
# The correlation coefficient between $r2$ and $M1$ is 0.10376493773566844
# The correlation coefficient between $r2$ and $f_{\rm s}$ is 0.04458152586743912
# The correlation coefficient between $r2$ and $\sigma_{\rm V}$ is 0.05124046835857567
# The correlation coefficient between $r2$ and $\Delta_{\rm r}$ is -0.02098439752621355
# The correlation coefficient between $r2$ and $\chi_{\rm DS}$ is 0.07017022237991534
# The correlation coefficient between $r2$ and $\dot{M}_\mathrm{a}$ is -0.027915669320735418
# The correlation coefficient between $r2$ and $f_{\rm ste}$ is 0.16662234564572306
# The correlation coefficient between $r2$ and $\eta$ is -0.13399153681513304
# The correlation coefficient between $T_{500}$ and $n_{e}$ is 0.3449273547292609
# The correlation coefficient between $T_{500}$ and $r2$ is 0.09491554339921211
# The correlation coefficient between $T_{500}$ and $T_{500}$ is 1.0
# The correlation coefficient between $T_{500}$ and $M1$ is 0.18506116471041506
# The correlation coefficient between $T_{500}$ and $f_{\rm s}$ is -0.12595094470351678
# The correlation coefficient between $T_{500}$ and $\sigma_{\rm V}$ is 0.9428405700687296
# The correlation coefficient between $T_{500}$ and $\Delta_{\rm r}$ is -0.13186510405533905
# The correlation coefficient between $T_{500}$ and $\chi_{\rm DS}$ is 0.03425522539758165
# The correlation coefficient between $T_{500}$ and $\dot{M}_\mathrm{a}$ is 0.39597597176896626
# The correlation coefficient between $T_{500}$ and $f_{\rm ste}$ is -0.09555314189028914
# The correlation coefficient between $T_{500}$ and $\eta$ is 0.27420904883911085
# The correlation coefficient between $M1$ and $n_{e}$ is -0.04094715663522743
# The correlation coefficient between $M1$ and $r2$ is 0.10376493773566844
# The correlation coefficient between $M1$ and $T_{500}$ is 0.18506116471041506
# The correlation coefficient between $M1$ and $M1$ is 1.0
# The correlation coefficient between $M1$ and $f_{\rm s}$ is 0.8234305487384855
# The correlation coefficient between $M1$ and $\sigma_{\rm V}$ is 0.27582912075985455
# The correlation coefficient between $M1$ and $\Delta_{\rm r}$ is 0.44586921117531236
# The correlation coefficient between $M1$ and $\chi_{\rm DS}$ is -0.49051716394176675
# The correlation coefficient between $M1$ and $\dot{M}_\mathrm{a}$ is 0.4638954464412788
# The correlation coefficient between $M1$ and $f_{\rm ste}$ is -0.2324861120624966
# The correlation coefficient between $M1$ and $\eta$ is 0.013190015513663843
# The correlation coefficient between $f_{\rm s}$ and $n_{e}$ is -0.22143954017387651
# The correlation coefficient between $f_{\rm s}$ and $r2$ is 0.04458152586743912
# The correlation coefficient between $f_{\rm s}$ and $T_{500}$ is -0.12595094470351678
# The correlation coefficient between $f_{\rm s}$ and $M1$ is 0.8234305487384855
# The correlation coefficient between $f_{\rm s}$ and $f_{\rm s}$ is 1.0000000000000002
# The correlation coefficient between $f_{\rm s}$ and $\sigma_{\rm V}$ is 0.02618622055960311
# The correlation coefficient between $f_{\rm s}$ and $\Delta_{\rm r}$ is 0.6010191275662234
# The correlation coefficient between $f_{\rm s}$ and $\chi_{\rm DS}$ is -0.6691508278566475
# The correlation coefficient between $f_{\rm s}$ and $\dot{M}_\mathrm{a}$ is 0.42255848781084404
# The correlation coefficient between $f_{\rm s}$ and $f_{\rm ste}$ is -0.40320418415433995
# The correlation coefficient between $f_{\rm s}$ and $\eta$ is 0.06765431601575134
# The correlation coefficient between $\sigma_{\rm V}$ and $n_{e}$ is 0.2975126827479209
# The correlation coefficient between $\sigma_{\rm V}$ and $r2$ is 0.05124046835857567
# The correlation coefficient between $\sigma_{\rm V}$ and $T_{500}$ is 0.9428405700687297
# The correlation coefficient between $\sigma_{\rm V}$ and $M1$ is 0.27582912075985455
# The correlation coefficient between $\sigma_{\rm V}$ and $f_{\rm s}$ is 0.026186220559603113
# The correlation coefficient between $\sigma_{\rm V}$ and $\sigma_{\rm V}$ is 1.0
# The correlation coefficient between $\sigma_{\rm V}$ and $\Delta_{\rm r}$ is 0.034074708183154036
# The correlation coefficient between $\sigma_{\rm V}$ and $\chi_{\rm DS}$ is -0.18156848977129272
# The correlation coefficient between $\sigma_{\rm V}$ and $\dot{M}_\mathrm{a}$ is 0.5975318126789811
# The correlation coefficient between $\sigma_{\rm V}$ and $f_{\rm ste}$ is -0.29154435066468365
# The correlation coefficient between $\sigma_{\rm V}$ and $\eta$ is 0.42451143900710947
# The correlation coefficient between $\Delta_{\rm r}$ and $n_{e}$ is -0.2801634554021336
# The correlation coefficient between $\Delta_{\rm r}$ and $r2$ is -0.02098439752621355
# The correlation coefficient between $\Delta_{\rm r}$ and $T_{500}$ is -0.13186510405533905
# The correlation coefficient between $\Delta_{\rm r}$ and $M1$ is 0.4458692111753124
# The correlation coefficient between $\Delta_{\rm r}$ and $f_{\rm s}$ is 0.6010191275662234
# The correlation coefficient between $\Delta_{\rm r}$ and $\sigma_{\rm V}$ is 0.034074708183154036
# The correlation coefficient between $\Delta_{\rm r}$ and $\Delta_{\rm r}$ is 1.0000000000000002
# The correlation coefficient between $\Delta_{\rm r}$ and $\chi_{\rm DS}$ is -0.7104400121085145
# The correlation coefficient between $\Delta_{\rm r}$ and $\dot{M}_\mathrm{a}$ is 0.498417479741059
# The correlation coefficient between $\Delta_{\rm r}$ and $f_{\rm ste}$ is -0.5100810475801285
# The correlation coefficient between $\Delta_{\rm r}$ and $\eta$ is 0.20569891477207913
# The correlation coefficient between $\chi_{\rm DS}$ and $n_{e}$ is 0.19050758712442703
# The correlation coefficient between $\chi_{\rm DS}$ and $r2$ is 0.07017022237991534
# The correlation coefficient between $\chi_{\rm DS}$ and $T_{500}$ is 0.03425522539758165
# The correlation coefficient between $\chi_{\rm DS}$ and $M1$ is -0.49051716394176675
# The correlation coefficient between $\chi_{\rm DS}$ and $f_{\rm s}$ is -0.6691508278566475
# The correlation coefficient between $\chi_{\rm DS}$ and $\sigma_{\rm V}$ is -0.18156848977129272
# The correlation coefficient between $\chi_{\rm DS}$ and $\Delta_{\rm r}$ is -0.7104400121085145
# The correlation coefficient between $\chi_{\rm DS}$ and $\chi_{\rm DS}$ is 1.0
# The correlation coefficient between $\chi_{\rm DS}$ and $\dot{M}_\mathrm{a}$ is -0.5710124624156195
# The correlation coefficient between $\chi_{\rm DS}$ and $f_{\rm ste}$ is 0.6438719831569892
# The correlation coefficient between $\chi_{\rm DS}$ and $\eta$ is -0.37037632481905036
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $n_{e}$ is 0.02942700541036627
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $r2$ is -0.027915669320735418
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $T_{500}$ is 0.3959759717689662
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $M1$ is 0.46389544644127884
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $f_{\rm s}$ is 0.42255848781084404
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $\sigma_{\rm V}$ is 0.597531812678981
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $\Delta_{\rm r}$ is 0.498417479741059
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $\chi_{\rm DS}$ is -0.5710124624156195
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $\dot{M}_\mathrm{a}$ is 0.9999999999999999
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $f_{\rm ste}$ is -0.64102775603082
# The correlation coefficient between $\dot{M}_\mathrm{a}$ and $\eta$ is 0.4020028973448283
# The correlation coefficient between $f_{\rm ste}$ and $n_{e}$ is 0.19558344431651506
# The correlation coefficient between $f_{\rm ste}$ and $r2$ is 0.16662234564572306
# The correlation coefficient between $f_{\rm ste}$ and $T_{500}$ is -0.09555314189028914
# The correlation coefficient between $f_{\rm ste}$ and $M1$ is -0.2324861120624966
# The correlation coefficient between $f_{\rm ste}$ and $f_{\rm s}$ is -0.40320418415433995
# The correlation coefficient between $f_{\rm ste}$ and $\sigma_{\rm V}$ is -0.29154435066468365
# The correlation coefficient between $f_{\rm ste}$ and $\Delta_{\rm r}$ is -0.5100810475801285
# The correlation coefficient between $f_{\rm ste}$ and $\chi_{\rm DS}$ is 0.6438719831569892
# The correlation coefficient between $f_{\rm ste}$ and $\dot{M}_\mathrm{a}$ is -0.6410277560308201
# The correlation coefficient between $f_{\rm ste}$ and $f_{\rm ste}$ is 1.0000000000000002
# The correlation coefficient between $f_{\rm ste}$ and $\eta$ is -0.4270735446785588
# The correlation coefficient between $\eta$ and $n_{e}$ is 0.015152284793599716
# The correlation coefficient between $\eta$ and $r2$ is -0.13399153681513304
# The correlation coefficient between $\eta$ and $T_{500}$ is 0.2742090488391108
# The correlation coefficient between $\eta$ and $M1$ is 0.013190015513663845
# The correlation coefficient between $\eta$ and $f_{\rm s}$ is 0.06765431601575134
# The correlation coefficient between $\eta$ and $\sigma_{\rm V}$ is 0.42451143900710947
# The correlation coefficient between $\eta$ and $\Delta_{\rm r}$ is 0.20569891477207916
# The correlation coefficient between $\eta$ and $\chi_{\rm DS}$ is -0.37037632481905036
# The correlation coefficient between $\eta$ and $\dot{M}_\mathrm{a}$ is 0.40200289734482836
# The correlation coefficient between $\eta$ and $f_{\rm ste}$ is -0.4270735446785588
# The correlation coefficient between $\eta$ and $\eta$ is 1.0000000000000002
# [[ 1.    0.11  0.34 -0.04 -0.22  0.3  -0.28  0.19  0.03  0.2   0.02]
#  [ 0.11  1.    0.09  0.1   0.04  0.05 -0.02  0.07 -0.03  0.17 -0.13]
#  [ 0.34  0.09  1.    0.19 -0.13  0.94 -0.13  0.03  0.4  -0.1   0.27]
#  [-0.04  0.1   0.19  1.    0.82  0.28  0.45 -0.49  0.46 -0.23  0.01]
#  [-0.22  0.04 -0.13  0.82  1.    0.03  0.6  -0.67  0.42 -0.4   0.07]
#  [ 0.3   0.05  0.94  0.28  0.03  1.    0.03 -0.18  0.6  -0.29  0.42]
#  [-0.28 -0.02 -0.13  0.45  0.6   0.03  1.   -0.71  0.5  -0.51  0.21]
#  [ 0.19  0.07  0.03 -0.49 -0.67 -0.18 -0.71  1.   -0.57  0.64 -0.37]
#  [ 0.03 -0.03  0.4   0.46  0.42  0.6   0.5  -0.57  1.   -0.64  0.4 ]
#  [ 0.2   0.17 -0.1  -0.23 -0.4  -0.29 -0.51  0.64 -0.64  1.   -0.43]
#  [ 0.02 -0.13  0.27  0.01  0.07  0.42  0.21 -0.37  0.4  -0.43  1.  ]]

# %% [markdown]
# ## test for correlation coefficient of map indicators

# %%
dSZ = np.loadtxt('../proxy/GadgetX_DS_SZ')[loc,1:]
dXray = np.loadtxt('../proxy/GadgetX_DS_Xray')[loc,1:]
dOffset = np.loadtxt('../proxy/GadgetX_DS_Offset')[loc,1:]

phyall = [dXray[:,2],dXray[:,-1],dSZ[:,-1],dOffset[:,1],dOffset[:,2],dOffset[:,5],dOffset[:,6]]
labelall = [r'$P_{\rm Xray}$', r'$M_{\rm Xray}$', r'$M_{\rm SZ}$', r'$R_{\rm SZ}$', r'$R_{\rm X}$',r'$O_{\rm BCG-SZ}$',r'$O_{\rm BCG-Py}$']
covall = np.zeros(shape = (7,7))

for i in range(7):
    for j in range(7):
        pro1 = phyall[i]
        pro2 = phyall[j]
        cov = np.cov(pro1,pro2)
        coveff = cov[0][1] / cov[0][0]**0.5 / cov[1][1]**0.5
        print('The correlation coefficient between %s and %s is %s' %(labelall[i],labelall[j],coveff))

        covall[i,j] = coveff
covall = np.around(covall, 2)
    
plt.figure(figsize = (6,4))
covmap = plt.imshow(np.abs(covall), cmap = 'Blues',vmin = 0, vmax = 1)
# Out:
# The correlation coefficient between $P_{\rm Xray}$ and $P_{\rm Xray}$ is 1.0000000000000002
# The correlation coefficient between $P_{\rm Xray}$ and $M_{\rm Xray}$ is 0.8820830412481152
# The correlation coefficient between $P_{\rm Xray}$ and $M_{\rm SZ}$ is 0.7013214130280008
# The correlation coefficient between $P_{\rm Xray}$ and $R_{\rm SZ}$ is 0.61763054059342
# The correlation coefficient between $P_{\rm Xray}$ and $R_{\rm X}$ is 0.6349998505896421
# The correlation coefficient between $P_{\rm Xray}$ and $O_{\rm BCG-SZ}$ is 0.5344437248726374
# The correlation coefficient between $P_{\rm Xray}$ and $O_{\rm BCG-Py}$ is 0.5782477758319009
# The correlation coefficient between $M_{\rm Xray}$ and $P_{\rm Xray}$ is 0.8820830412481152
# The correlation coefficient between $M_{\rm Xray}$ and $M_{\rm Xray}$ is 1.0
# The correlation coefficient between $M_{\rm Xray}$ and $M_{\rm SZ}$ is 0.8265608543525793
# The correlation coefficient between $M_{\rm Xray}$ and $R_{\rm SZ}$ is 0.6801085880905723
# The correlation coefficient between $M_{\rm Xray}$ and $R_{\rm X}$ is 0.7052499404246946
# The correlation coefficient between $M_{\rm Xray}$ and $O_{\rm BCG-SZ}$ is 0.6036073472358578
# The correlation coefficient between $M_{\rm Xray}$ and $O_{\rm BCG-Py}$ is 0.6436235133094689
# The correlation coefficient between $M_{\rm SZ}$ and $P_{\rm Xray}$ is 0.7013214130280008
# The correlation coefficient between $M_{\rm SZ}$ and $M_{\rm Xray}$ is 0.8265608543525793
# The correlation coefficient between $M_{\rm SZ}$ and $M_{\rm SZ}$ is 1.0000000000000002
# The correlation coefficient between $M_{\rm SZ}$ and $R_{\rm SZ}$ is 0.7910880567223662
# The correlation coefficient between $M_{\rm SZ}$ and $R_{\rm X}$ is 0.7153242863426872
# The correlation coefficient between $M_{\rm SZ}$ and $O_{\rm BCG-SZ}$ is 0.6634791546110724
# The correlation coefficient between $M_{\rm SZ}$ and $O_{\rm BCG-Py}$ is 0.6213819361742223
# The correlation coefficient between $R_{\rm SZ}$ and $P_{\rm Xray}$ is 0.61763054059342
# The correlation coefficient between $R_{\rm SZ}$ and $M_{\rm Xray}$ is 0.6801085880905724
# The correlation coefficient between $R_{\rm SZ}$ and $M_{\rm SZ}$ is 0.7910880567223662
# The correlation coefficient between $R_{\rm SZ}$ and $R_{\rm SZ}$ is 1.0
# The correlation coefficient between $R_{\rm SZ}$ and $R_{\rm X}$ is 0.8211338093844854
# The correlation coefficient between $R_{\rm SZ}$ and $O_{\rm BCG-SZ}$ is 0.7703912930351808
# The correlation coefficient between $R_{\rm SZ}$ and $O_{\rm BCG-Py}$ is 0.6825792870405352
# The correlation coefficient between $R_{\rm X}$ and $P_{\rm Xray}$ is 0.6349998505896421
# The correlation coefficient between $R_{\rm X}$ and $M_{\rm Xray}$ is 0.7052499404246945
# The correlation coefficient between $R_{\rm X}$ and $M_{\rm SZ}$ is 0.7153242863426872
# The correlation coefficient between $R_{\rm X}$ and $R_{\rm SZ}$ is 0.8211338093844853
# The correlation coefficient between $R_{\rm X}$ and $R_{\rm X}$ is 1.0
# The correlation coefficient between $R_{\rm X}$ and $O_{\rm BCG-SZ}$ is 0.7169364744051293
# The correlation coefficient between $R_{\rm X}$ and $O_{\rm BCG-Py}$ is 0.8542184782615809
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $P_{\rm Xray}$ is 0.5344437248726374
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $M_{\rm Xray}$ is 0.6036073472358578
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $M_{\rm SZ}$ is 0.6634791546110724
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $R_{\rm SZ}$ is 0.7703912930351808
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $R_{\rm X}$ is 0.7169364744051293
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $O_{\rm BCG-SZ}$ is 0.9999999999999999
# The correlation coefficient between $O_{\rm BCG-SZ}$ and $O_{\rm BCG-Py}$ is 0.8793896467928551
# The correlation coefficient between $O_{\rm BCG-Py}$ and $P_{\rm Xray}$ is 0.5782477758319009
# The correlation coefficient between $O_{\rm BCG-Py}$ and $M_{\rm Xray}$ is 0.6436235133094688
# The correlation coefficient between $O_{\rm BCG-Py}$ and $M_{\rm SZ}$ is 0.6213819361742223
# The correlation coefficient between $O_{\rm BCG-Py}$ and $R_{\rm SZ}$ is 0.6825792870405352
# The correlation coefficient between $O_{\rm BCG-Py}$ and $R_{\rm X}$ is 0.8542184782615809
# The correlation coefficient between $O_{\rm BCG-Py}$ and $O_{\rm BCG-SZ}$ is 0.8793896467928551
# The correlation coefficient between $O_{\rm BCG-Py}$ and $O_{\rm BCG-Py}$ is 1.0
# <img src="data:image/png;base64,..." width="600">

# %%
plt.figure()

plt.errorbar(1,1,yerr = 2, marker = 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <ErrorbarContainer object of 3 artists>
